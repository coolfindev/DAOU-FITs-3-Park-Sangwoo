# %% [markdown]
# <a href="https://colab.research.google.com/github/coolfindev/DAOU-FITs-3-Park-Sangwoo/blob/%EC%8B%A4%EC%8A%B5/%5BCS%5D250108-%EC%8B%A4%EC%8A%B522%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import unittest
from mymodule import add, subtract
# print(add(1,2))

class TestMath(unittest.TestCase):
    def test_add(self):
        self.assertEqual(add(1,2),3)
    def test_subtract(self):
        self.assertEqual(subtract(5,3),2)
    def test_add_negative(self):
        self.assertEqual(add(-1,-2),-3)
    def test_subtract_negative(self):
        self.assertEqual(subtract(-5,-3),-2)

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.011s
#
# OK
