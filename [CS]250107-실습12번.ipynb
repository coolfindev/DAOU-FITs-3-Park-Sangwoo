# %% [markdown]
# <a href="https://colab.research.google.com/github/coolfindev/DAOU-FITs-3-Park-Sangwoo/blob/%EC%8B%A4%EC%8A%B5/%5BCS%5D250107-%EC%8B%A4%EC%8A%B512%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#정수로 이루어진 배열 초기화
arr = [1,2,3,4,5]

#특정 값으로 초기화
arr_zeros = [0] * 5 # [0,0,0,0,0]
arr_ones = [1] * 5 #[1,1,1,1,1]

# %%
arr = [10,20,30,40,50]
print(arr[0]) #10
print(arr[2]) #30
print(arr[-1]) #50(뒤에서 첫번째 값)
# Out:
# 10
# 30
# 50

# %%
arr = [1,2,3,4,5]
print(len(arr)) #5
# Out:
# 5
