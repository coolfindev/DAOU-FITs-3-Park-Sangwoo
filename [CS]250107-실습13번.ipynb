# %% [markdown]
# <a href="https://colab.research.google.com/github/coolfindev/DAOU-FITs-3-Park-Sangwoo/blob/%EC%8B%A4%EC%8A%B5/%5BCS%5D250107-%EC%8B%A4%EC%8A%B513%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#배열의 요소 추가/삽입
arr = [1,2,3]
arr.append(4)
arr.insert(1,10)
arr_ones = [1] * 5

arr
# Out:
# [1, 10, 2, 3, 4]

# %%
#배열 요소 삭제
arr = [10,20,30,40,50]
arr.remove(30)
arr.pop()
arr.pop(0)

arr
# Out:
# [20, 40]

# %%
#배열 요소 수정
arr=[1,2,3,4,5]
arr[2] = 99

arr
# Out:
# [1, 2, 99, 4, 5]

# %%
#배열 합치기
arr1 = [1,2,3]
arr2 = [4,5,6]
arr3 = arr1 + arr2
arr1.extend(arr2)

print(arr3)
print(arr1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
